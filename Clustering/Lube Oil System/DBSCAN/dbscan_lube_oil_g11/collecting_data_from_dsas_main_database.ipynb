# %%
import pyodbc
import pymysql
import time
from datetime import datetime
import threading
import signal
import sys

# ================== تنظیمات ==================
INTERVAL_SECONDS = 60 * 60  # هر 5 دقیقه
RUNNING = True  # برای توقف با Ctrl+C

# ================== اتصالات ==================
def get_sql_connection():
    return pyodbc.connect(
    'DRIVER={SQL Server};'
    'SERVER=MKZ-DSAS\\DSAS;'
    'DATABASE=DSAS;'
    'UID=datadriven;'
    'PWD=5Rdx@4Rfv1355'
    )

def get_mysql_connection():
    return pymysql.connect(
        host="127.0.0.1", port=3306, user="root", password="", database="dsas",
        charset="utf8mb4", cursorclass=pymysql.cursors.DictCursor
    )

# ================== لیست AssetIDها ==================
asset_ids = [8341, 8342, 8343, 8344, 8346, 9286, 9287]
field_map = {8341: 'AssetID_8341', 8342: 'AssetID_8342', 8343: 'AssetID_8343',
             8344: 'AssetID_8344', 8346: 'AssetID_8346', 9286: 'AssetID_9286', 9287: 'AssetID_9287'}

# ================== تابع اصلی (همون کد قبلی) ==================
def run_task():
    print(f"\n{'='*60}")
    print(f"اجرای وظیفه: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
    print(f"{'='*60}")

    conn_sql = None
    conn_mysql = None
    cursor = None

    try:
        # --- اتصال ---
        print("اتصال به SQL Server...")
        conn_sql = get_sql_connection()
        print("اتصال به MySQL...")
        conn_mysql = get_mysql_connection()

        # --- خواندن TimeStamps موجود ---
        print("خواندن TimeStamps موجود...")
        existing_ts = set()
        with conn_mysql.cursor() as c:
            c.execute("SELECT TimeStamps FROM main_table_mhi_lube_oil_11 WHERE unitID = 11")
            for row in c.fetchall():
                existing_ts.add(row['TimeStamps'])
        print(f"{len(existing_ts)} رکورد موجود است.")

        # --- خواندن 10 رکورد آخر برای 8341 ---
        print("خواندن 10 رکورد آخر برای AssetID=8341...")
        query_8341 = """
        SELECT TOP 1000 [Value], [RecordTime], [RecordDate], [DateTime], [TimeStamp]
        FROM [DSAS].[PDA].[Periodic_Values]
        WHERE [UnitID] = 11 AND [AssetID] = 8341
        ORDER BY [DateTime] DESC
        """
        cursor = conn_sql.cursor()
        cursor.execute(query_8341)
        rows_8341 = cursor.fetchall()

        if not rows_8341:
            print("هیچ داده‌ای برای AssetID=8341 پیدا نشد.")
            return

        inserted_count = 0
        for idx, row in enumerate(rows_8341):
            ts = row.TimeStamp
            if ts in existing_ts:
                print(f"رکورد {idx+1}: TimeStamps={ts} تکراری → رد شد.")
                continue

            dt = row.DateTime
            print(f"\n--- درج رکورد {idx+1} | TimeStamps={ts} ---")

            # درج اولیه
            insert_sql = """
            INSERT INTO main_table_mhi_lube_oil_11
            (unitID, AssetID_8341, RecordTime, RecordDate, DateTime, TimeStamps)
            VALUES (%s, %s, %s, %s, %s, %s)
            """
            try:
                with conn_mysql.cursor() as c:
                    c.execute(insert_sql, (11, row.Value, 
                                         dt.strftime('%H:%M:%S'), dt.strftime('%Y-%m-%d'), dt, ts))
                conn_mysql.commit()
                print("رکورد درج شد.")
                inserted_count += 1
            except Exception as e:
                print(f"خطا در درج: {e}")
                continue

            # آپدیت 6 فیلد دیگر
            for aid in [8342, 8343, 8344, 8346, 9286, 9287]:
                field = field_map[aid]
                near_sql = f"""
                SELECT TOP 1 [Value] FROM [DSAS].[PDA].[Periodic_Values]
                WHERE [UnitID]=11 AND [AssetID]=? AND ABS([TimeStamp] - ?) < 1000
                ORDER BY ABS([TimeStamp] - ?)
                """
                cursor.execute(near_sql, (aid, ts, ts))
                near_row = cursor.fetchone()

                if near_row and near_row.Value is not None:
                    value = float(near_row.Value)
                    source = "نزدیک"
                else:
                    avg_sql = f"""
                    SELECT AVG(CAST([Value] AS FLOAT)) FROM (
                        SELECT TOP 10 [Value] FROM [DSAS].[PDA].[Periodic_Values]
                        WHERE [UnitID]=11 AND [AssetID]=?
                        ORDER BY [DateTime] DESC
                    ) sub
                    """
                    cursor.execute(avg_sql, (aid,))
                    avg_row = cursor.fetchone()
                    value = round(float(avg_row[0]), 4) if avg_row and avg_row[0] else None
                    source = "میانگین"

                if value is not None:
                    update_sql = f"UPDATE main_table_mhi_lube_oil_11 SET {field} = %s WHERE TimeStamps = %s"
                    try:
                        with conn_mysql.cursor() as c:
                            c.execute(update_sql, (value, ts))
                        conn_mysql.commit()
                        print(f"   {field} = {value} ({source})")
                    except Exception as e:
                        print(f"   خطا در آپدیت {field}: {e}")
                else:
                    print(f"   {field}: داده‌ای پیدا نشد.")

        print(f"\nنتیجه این دور: {inserted_count} رکورد جدید درج و آپدیت شد.")

    except Exception as e:
        print(f"خطای کلی: {e}")
    finally:
        if cursor: cursor.close()
        if conn_sql: conn_sql.close()
        if conn_mysql: conn_mysql.close()

# ================== حلقه اصلی (هر 5 دقیقه) ==================
def scheduler():
    run_task()
    # while RUNNING:
    #     run_task()
    #     print(f"\nمنتظر {INTERVAL_SECONDS//60} دقیقه بعدی...")
    #     # خوابیدن با چک کردن هر ثانیه (برای Ctrl+C)
    #     for _ in range(INTERVAL_SECONDS):
    #         if not RUNNING:
    #             break
    #         time.sleep(1)

# ================== توقف با Ctrl+C ==================
def signal_handler(sig, frame):
    global RUNNING
    print('\nدریافت سیگنال توقف (Ctrl+C). در حال خروج...')
    RUNNING = False

signal.signal(signal.SIGINT, signal_handler)

# ================== اجرا ==================
if __name__ == "__main__":
    print("اسکریپت هر 60 دقیقه یکبار اجرا میشود...")
    print("برای توقف، Ctrl+C بزنید.")
    scheduler()
    print("اسکریپت با موفقیت متوقف شد.")
# Out:
# اسکریپت هر 60 دقیقه یکبار اجرا میشود...
# برای توقف، Ctrl+C بزنید.
#
# ============================================================
# اجرای وظیفه: 2025-11-17 13:59:55
# ============================================================
# اتصال به SQL Server...
# اتصال به MySQL...
# خواندن TimeStamps موجود...
# 875 رکورد موجود است.
# خواندن 10 رکورد آخر برای AssetID=8341...
#
# --- درج رکورد 1 | TimeStamps=1763340043 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.2 (نزدیک)
#
# --- درج رکورد 2 | TimeStamps=1763325657 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.2 (نزدیک)
#
# --- درج رکورد 3 | TimeStamps=1763311996 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 4 | TimeStamps=1763298469 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.7 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 5 | TimeStamps=1763282014 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.7 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 6 | TimeStamps=1763269510 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.7 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 7 | TimeStamps=1763259119 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 8 | TimeStamps=1763239246 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 9 | TimeStamps=1763225924 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 10 | TimeStamps=1763210597 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 11 | TimeStamps=1763196598 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 12 | TimeStamps=1763182451 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.2 (نزدیک)
#
# --- درج رکورد 13 | TimeStamps=1763172992 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 14 | TimeStamps=1763153044 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 15 | TimeStamps=1763140569 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 16 | TimeStamps=1763127443 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.7 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 17 | TimeStamps=1763109282 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.7 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 18 | TimeStamps=1763098032 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.7 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 19 | TimeStamps=1763086121 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 70.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 20 | TimeStamps=1763066364 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 70.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 21 | TimeStamps=1763054737 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 70.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 22 | TimeStamps=1763039409 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 23 | TimeStamps=1763023200 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 24 | TimeStamps=1763012230 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 25 | TimeStamps=1762997389 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 26 | TimeStamps=1762980399 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 27 | TimeStamps=1762967091 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 28 | TimeStamps=1762952877 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 70.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 29 | TimeStamps=1762936759 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 70.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 30 | TimeStamps=1762925198 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 31 | TimeStamps=1762913573 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 32 | TimeStamps=1762894149 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 33 | TimeStamps=1762882910 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 34 | TimeStamps=1762866265 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 35 | TimeStamps=1762850805 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 36 | TimeStamps=1762837605 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 37 | TimeStamps=1762827357 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 38 | TimeStamps=1762807782 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 39 | TimeStamps=1762797257 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 40 | TimeStamps=1762782122 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 41 | TimeStamps=1762764333 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 42 | TimeStamps=1762751283 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 43 | TimeStamps=1762739370 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.7 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 44 | TimeStamps=1762720987 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.7 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 45 | TimeStamps=1762707713 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.7 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 46 | TimeStamps=1762697230 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 47 | TimeStamps=1762677744 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 48 | TimeStamps=1762666163 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 49 | TimeStamps=1762648878 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 50 | TimeStamps=1762634820 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 51 | TimeStamps=1762620914 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 52 | TimeStamps=1762605898 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 53 | TimeStamps=1762591088 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 54 | TimeStamps=1762578252 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 55 | TimeStamps=1762567897 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.7 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 56 | TimeStamps=1762548052 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.7 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 57 | TimeStamps=1762534769 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.7 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 58 | TimeStamps=1762519371 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 59 | TimeStamps=1762505567 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 60 | TimeStamps=1762492445 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 61 | TimeStamps=1762481703 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.7 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 62 | TimeStamps=1762461453 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.7 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 63 | TimeStamps=1762451928 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.7 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 64 | TimeStamps=1762436907 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.7 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 65 | TimeStamps=1762418428 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.7 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 66 | TimeStamps=1762406047 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.7 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 67 | TimeStamps=1762395320 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.7 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 68 | TimeStamps=1762375098 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.7 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 69 | TimeStamps=1762363401 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.7 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 70 | TimeStamps=1762350621 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.7 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 71 | TimeStamps=1762331676 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.7 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 72 | TimeStamps=1762319714 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.7 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 73 | TimeStamps=1762304873 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 74 | TimeStamps=1762289160 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 75 | TimeStamps=1762275976 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 76 | TimeStamps=1762265261 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.7 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 77 | TimeStamps=1762245654 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.7 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 78 | TimeStamps=1762233102 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.7 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 79 | TimeStamps=1762220674 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.7 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 80 | TimeStamps=1762202503 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.7 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 81 | TimeStamps=1762190435 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 7.6 (نزدیک)
#    AssetID_9286 = 7.7 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 82 | TimeStamps=1762174400 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 83 | TimeStamps=1762146671 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 0.12 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 84 | TimeStamps=1762136392 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 85 | TimeStamps=1762116436 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 86 | TimeStamps=1762106068 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 87 | TimeStamps=1762090249 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 88 | TimeStamps=1762072430 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 89 | TimeStamps=1762061593 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 90 | TimeStamps=1762048083 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 91 | TimeStamps=1762029806 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 92 | TimeStamps=1762017639 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 93 | TimeStamps=1762003755 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 94 | TimeStamps=1761987246 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 95 | TimeStamps=1761975881 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 96 | TimeStamps=1761957740 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 97 | TimeStamps=1761943403 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 98 | TimeStamps=1761929519 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.2 (نزدیک)
#
# --- درج رکورد 99 | TimeStamps=1761915439 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 100 | TimeStamps=1761899965 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 101 | TimeStamps=1761886861 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 102 | TimeStamps=1761877190 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 103 | TimeStamps=1761857434 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 104 | TimeStamps=1761842437 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 105 | TimeStamps=1761828708 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 106 | TimeStamps=1761814228 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 107 | TimeStamps=1761800047 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.2 (نزدیک)
#
# --- درج رکورد 108 | TimeStamps=1761790908 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 109 | TimeStamps=1761770186 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 110 | TimeStamps=1761760555 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 111 | TimeStamps=1761744383 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 112 | TimeStamps=1761727612 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.2 (نزدیک)
#
# --- درج رکورد 113 | TimeStamps=1761713757 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.2 (نزدیک)
#
# --- درج رکورد 114 | TimeStamps=1761704130 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 115 | TimeStamps=1761684348 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 116 | TimeStamps=1761669708 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 117 | TimeStamps=1761659200 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 118 | TimeStamps=1761642680 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 119 | TimeStamps=1761629572 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 120 | TimeStamps=1761614651 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 121 | TimeStamps=1761598146 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 122 | TimeStamps=1761584314 ---
# رکورد درج شد.
#    AssetID_8342 = 10.9 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 123 | TimeStamps=1761571109 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 124 | TimeStamps=1761554665 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 125 | TimeStamps=1761542363 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 126 | TimeStamps=1761531130 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 127 | TimeStamps=1761514137 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 128 | TimeStamps=1761498067 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 129 | TimeStamps=1761483109 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 130 | TimeStamps=1761468641 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 131 | TimeStamps=1761455372 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 132 | TimeStamps=1761444328 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 133 | TimeStamps=1761424637 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 134 | TimeStamps=1761413333 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 135 | TimeStamps=1761397936 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 136 | TimeStamps=1761381828 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 137 | TimeStamps=1761369212 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 138 | TimeStamps=1761357989 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 139 | TimeStamps=1761338657 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 140 | TimeStamps=1761323678 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 2.0 (نزدیک)
#
# --- درج رکورد 141 | TimeStamps=1761310613 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 142 | TimeStamps=1761295567 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 143 | TimeStamps=1761284386 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 144 | TimeStamps=1761270949 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 145 | TimeStamps=1761252275 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 146 | TimeStamps=1761238549 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 147 | TimeStamps=1761224689 ---
# رکورد درج شد.
#    AssetID_8342 = 11.1 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.8 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 148 | TimeStamps=1761209062 ---
# رکورد درج شد.
#    AssetID_8342 = 11.1 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.8 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 149 | TimeStamps=1761196253 ---
# رکورد درج شد.
#    AssetID_8342 = 11.1 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.8 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 150 | TimeStamps=1761183829 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.7 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 151 | TimeStamps=1761165658 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.7 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 152 | TimeStamps=1761152465 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.7 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 153 | TimeStamps=1761137263 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 154 | TimeStamps=1761122746 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 155 | TimeStamps=1761108962 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 156 | TimeStamps=1761095317 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 157 | TimeStamps=1761079055 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 158 | TimeStamps=1761068800 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 159 | TimeStamps=1761053146 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.7 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 160 | TimeStamps=1761036534 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.7 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 161 | TimeStamps=1761023217 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.7 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 162 | TimeStamps=1761012655 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 163 | TimeStamps=1760992801 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 164 | TimeStamps=1760978799 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 165 | TimeStamps=1760966487 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 166 | TimeStamps=1760950439 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 167 | TimeStamps=1760940276 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 168 | TimeStamps=1760920799 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 169 | TimeStamps=1760906573 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 170 | TimeStamps=1760893047 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 171 | TimeStamps=1760877835 ---
# رکورد درج شد.
#    AssetID_8342 = 11.1 (نزدیک)
#    AssetID_8343 = 70.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 172 | TimeStamps=1760862972 ---
# رکورد درج شد.
#    AssetID_8342 = 11.1 (نزدیک)
#    AssetID_8343 = 70.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 173 | TimeStamps=1760853020 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 70.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 174 | TimeStamps=1760840174 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 175 | TimeStamps=1760820459 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 176 | TimeStamps=1760806848 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 177 | TimeStamps=1760792391 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 70.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 178 | TimeStamps=1760776384 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 70.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 179 | TimeStamps=1760766088 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 70.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 180 | TimeStamps=1760754137 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 181 | TimeStamps=1760733655 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 182 | TimeStamps=1760723620 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 183 | TimeStamps=1760707943 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 184 | TimeStamps=1760690248 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 185 | TimeStamps=1760677259 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 186 | TimeStamps=1760663819 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 187 | TimeStamps=1760647771 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 188 | TimeStamps=1760633884 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 189 | TimeStamps=1760622788 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 190 | TimeStamps=1760604205 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 191 | TimeStamps=1760592996 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 192 | TimeStamps=1760575411 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 193 | TimeStamps=1760562586 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 194 | TimeStamps=1760547393 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
# ...
# رکورد درج شد.
#    AssetID_8342 = 11.1 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 487 | TimeStamps=1756327390 ---
# رکورد درج شد.
#    AssetID_8342 = 11.1 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 488 | TimeStamps=1756313188 ---
# رکورد درج شد.
#    AssetID_8342 = 11.2 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 489 | TimeStamps=1756298716 ---
# رکورد درج شد.
#    AssetID_8342 = 11.2 (نزدیک)
#    AssetID_8343 = 74.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 490 | TimeStamps=1756285192 ---
# رکورد درج شد.
#    AssetID_8342 = 11.2 (نزدیک)
#    AssetID_8343 = 76.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 491 | TimeStamps=1756271446 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 492 | TimeStamps=1756256042 ---
# رکورد درج شد.
#    AssetID_8342 = 11.0 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 493 | TimeStamps=1755938829 ---
# رکورد درج شد.
#    AssetID_8342 = 11.2 (نزدیک)
#    AssetID_8343 = 74.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 494 | TimeStamps=1755926264 ---
# رکورد درج شد.
#    AssetID_8342 = 11.2 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 495 | TimeStamps=1755915677 ---
# رکورد درج شد.
#    AssetID_8342 = 11.2 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.25 (نزدیک)
#
# --- درج رکورد 496 | TimeStamps=1755895296 ---
# رکورد درج شد.
#    AssetID_8342 = 11.2 (نزدیک)
#    AssetID_8343 = 70.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.25 (نزدیک)
#
# --- درج رکورد 497 | TimeStamps=1755882589 ---
# رکورد درج شد.
#    AssetID_8342 = 11.2 (نزدیک)
#    AssetID_8343 = 70.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.25 (نزدیک)
#
# --- درج رکورد 498 | TimeStamps=1755871442 ---
# رکورد درج شد.
#    AssetID_8342 = 11.2 (نزدیک)
#    AssetID_8343 = 72.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 499 | TimeStamps=1755854536 ---
# رکورد درج شد.
#    AssetID_8342 = 11.2 (نزدیک)
#    AssetID_8343 = 73.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.41 (نزدیک)
#
# --- درج رکورد 500 | TimeStamps=1755839974 ---
# رکورد درج شد.
#    AssetID_8342 = 11.2 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.41 (نزدیک)
#
# --- درج رکورد 501 | TimeStamps=1755827829 ---
# رکورد درج شد.
#    AssetID_8342 = 11.2 (نزدیک)
#    AssetID_8343 = 70.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.41 (نزدیک)
#
# --- درج رکورد 502 | TimeStamps=1755808839 ---
# رکورد درج شد.
#    AssetID_8342 = 11.2 (نزدیک)
#    AssetID_8343 = 71.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.41 (نزدیک)
#
# --- درج رکورد 503 | TimeStamps=1755795463 ---
# رکورد درج شد.
#    AssetID_8342 = 11.2 (نزدیک)
#    AssetID_8343 = 71.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.41 (نزدیک)
#
# --- درج رکورد 504 | TimeStamps=1755784452 ---
# رکورد درج شد.
#    AssetID_8342 = 11.2 (نزدیک)
#    AssetID_8343 = 72.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.29 (نزدیک)
#
# --- درج رکورد 505 | TimeStamps=1755765741 ---
# رکورد درج شد.
#    AssetID_8342 = 11.2 (نزدیک)
#    AssetID_8343 = 74.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.29 (نزدیک)
#
# --- درج رکورد 506 | TimeStamps=1755755318 ---
# رکورد درج شد.
#    AssetID_8342 = 11.2 (نزدیک)
#    AssetID_8343 = 70.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.29 (نزدیک)
#
# --- درج رکورد 507 | TimeStamps=1755737031 ---
# رکورد درج شد.
#    AssetID_8342 = 11.2 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.3 (نزدیک)
#
# --- درج رکورد 508 | TimeStamps=1755722685 ---
# رکورد درج شد.
#    AssetID_8342 = 11.2 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.3 (نزدیک)
#
# --- درج رکورد 509 | TimeStamps=1755709732 ---
# رکورد درج شد.
#    AssetID_8342 = 11.3 (نزدیک)
#    AssetID_8343 = 71.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 510 | TimeStamps=1755697456 ---
# رکورد درج شد.
#    AssetID_8342 = 11.2 (نزدیک)
#    AssetID_8343 = 76.0 (نزدیک)
#    AssetID_8344 = -220.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.23 (نزدیک)
#
# --- درج رکورد 511 | TimeStamps=1755679966 ---
# رکورد درج شد.
#    AssetID_8342 = 11.2 (نزدیک)
#    AssetID_8343 = 73.0 (نزدیک)
#    AssetID_8344 = -220.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.23 (نزدیک)
#
# --- درج رکورد 512 | TimeStamps=1755667517 ---
# رکورد درج شد.
#    AssetID_8342 = 11.2 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -220.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.23 (نزدیک)
#
# --- درج رکورد 513 | TimeStamps=1755656103 ---
# رکورد درج شد.
#    AssetID_8342 = 11.2 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.25 (نزدیک)
#
# --- درج رکورد 514 | TimeStamps=1755636194 ---
# رکورد درج شد.
#    AssetID_8342 = 11.2 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 515 | TimeStamps=1755623294 ---
# رکورد درج شد.
#    AssetID_8342 = 11.3 (نزدیک)
#    AssetID_8343 = 71.0 (نزدیک)
#    AssetID_8344 = -220.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.21 (نزدیک)
#
# --- درج رکورد 516 | TimeStamps=1755609434 ---
# رکورد درج شد.
#    AssetID_8342 = 11.3 (نزدیک)
#    AssetID_8343 = 76.0 (نزدیک)
#    AssetID_8344 = -220.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 517 | TimeStamps=1755593534 ---
# رکورد درج شد.
#    AssetID_8342 = 11.3 (نزدیک)
#    AssetID_8343 = 76.0 (نزدیک)
#    AssetID_8344 = -220.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 518 | TimeStamps=1755581039 ---
# رکورد درج شد.
#    AssetID_8342 = 11.3 (نزدیک)
#    AssetID_8343 = 70.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 519 | TimeStamps=1755570193 ---
# رکورد درج شد.
#    AssetID_8342 = 11.2 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.23 (نزدیک)
#
# --- درج رکورد 520 | TimeStamps=1755549752 ---
# رکورد درج شد.
#    AssetID_8342 = 11.2 (نزدیک)
#    AssetID_8343 = 72.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.23 (نزدیک)
#
# --- درج رکورد 521 | TimeStamps=1755539637 ---
# رکورد درج شد.
#    AssetID_8342 = 11.2 (نزدیک)
#    AssetID_8343 = 72.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.23 (نزدیک)
#
# --- درج رکورد 522 | TimeStamps=1755526211 ---
# رکورد درج شد.
#    AssetID_8342 = 11.2 (نزدیک)
#    AssetID_8343 = 74.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.23 (نزدیک)
#
# --- درج رکورد 523 | TimeStamps=1755506892 ---
# رکورد درج شد.
#    AssetID_8342 = 11.2 (نزدیک)
#    AssetID_8343 = 77.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.23 (نزدیک)
#
# --- درج رکورد 524 | TimeStamps=1755494212 ---
# رکورد درج شد.
#    AssetID_8342 = 11.2 (نزدیک)
#    AssetID_8343 = 70.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.3 (نزدیک)
#
# --- درج رکورد 525 | TimeStamps=1755483391 ---
# رکورد درج شد.
#    AssetID_8342 = 11.2 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 526 | TimeStamps=1755463324 ---
# رکورد درج شد.
#    AssetID_8342 = 11.2 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 527 | TimeStamps=1755451812 ---
# رکورد درج شد.
#    AssetID_8342 = 11.2 (نزدیک)
#    AssetID_8343 = 70.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 528 | TimeStamps=1755437168 ---
# رکورد درج شد.
#    AssetID_8342 = 11.2 (نزدیک)
#    AssetID_8343 = 76.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 529 | TimeStamps=1755421406 ---
# رکورد درج شد.
#    AssetID_8342 = 11.2 (نزدیک)
#    AssetID_8343 = 70.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 530 | TimeStamps=1755407956 ---
# رکورد درج شد.
#    AssetID_8342 = 11.2 (نزدیک)
#    AssetID_8343 = 70.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 531 | TimeStamps=1755394371 ---
# رکورد درج شد.
#    AssetID_8342 = 11.2 (نزدیک)
#    AssetID_8343 = 68.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 532 | TimeStamps=1755377333 ---
# رکورد درج شد.
#    AssetID_8342 = 11.2 (نزدیک)
#    AssetID_8343 = 70.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 533 | TimeStamps=1755363885 ---
# رکورد درج شد.
#    AssetID_8342 = 11.2 (نزدیک)
#    AssetID_8343 = 70.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.22 (نزدیک)
#
# --- درج رکورد 534 | TimeStamps=1755350759 ---
# رکورد درج شد.
#    AssetID_8342 = 11.3 (نزدیک)
#    AssetID_8343 = 72.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.4 (نزدیک)
#
# --- درج رکورد 535 | TimeStamps=1755333153 ---
# رکورد درج شد.
#    AssetID_8342 = 11.3 (نزدیک)
#    AssetID_8343 = 74.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.4 (نزدیک)
#
# --- درج رکورد 536 | TimeStamps=1755321414 ---
# رکورد درج شد.
#    AssetID_8342 = 11.3 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.4 (نزدیک)
#
# --- درج رکورد 537 | TimeStamps=1755310395 ---
# رکورد درج شد.
#    AssetID_8342 = 11.3 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.32 (نزدیک)
#
# --- درج رکورد 538 | TimeStamps=1755290882 ---
# رکورد درج شد.
#    AssetID_8342 = 11.3 (نزدیک)
#    AssetID_8343 = 69.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.41 (نزدیک)
#
# --- درج رکورد 539 | TimeStamps=1755277680 ---
# رکورد درج شد.
#    AssetID_8342 = 11.3 (نزدیک)
#    AssetID_8343 = 70.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.41 (نزدیک)
#
# --- درج رکورد 540 | TimeStamps=1755263063 ---
# رکورد درج شد.
#    AssetID_8342 = 11.3 (نزدیک)
#    AssetID_8343 = 76.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.25 (نزدیک)
#
# --- درج رکورد 541 | TimeStamps=1755247686 ---
# رکورد درج شد.
#    AssetID_8342 = 11.3 (نزدیک)
#    AssetID_8343 = 74.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.4 (نزدیک)
#
# --- درج رکورد 542 | TimeStamps=1755234498 ---
# رکورد درج شد.
#    AssetID_8342 = 11.3 (نزدیک)
#    AssetID_8343 = 74.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.4 (نزدیک)
#
# --- درج رکورد 543 | TimeStamps=1755223983 ---
# رکورد درج شد.
#    AssetID_8342 = 11.3 (نزدیک)
#    AssetID_8343 = 72.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.29 (نزدیک)
#
# --- درج رکورد 544 | TimeStamps=1755204184 ---
# رکورد درج شد.
#    AssetID_8342 = 11.3 (نزدیک)
#    AssetID_8343 = 72.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.29 (نزدیک)
#
# --- درج رکورد 545 | TimeStamps=1755192959 ---
# رکورد درج شد.
#    AssetID_8342 = 11.3 (نزدیک)
#    AssetID_8343 = 72.0 (نزدیک)
#    AssetID_8344 = -240.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.29 (نزدیک)
#
# --- درج رکورد 546 | TimeStamps=1755175204 ---
# رکورد درج شد.
#    AssetID_8342 = 11.3 (نزدیک)
#    AssetID_8343 = 78.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.23 (نزدیک)
#
# --- درج رکورد 547 | TimeStamps=1755161292 ---
# رکورد درج شد.
#    AssetID_8342 = 11.3 (نزدیک)
#    AssetID_8343 = 78.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.23 (نزدیک)
#
# --- درج رکورد 548 | TimeStamps=1755148297 ---
# رکورد درج شد.
#    AssetID_8342 = 11.3 (نزدیک)
#    AssetID_8343 = 76.0 (نزدیک)
#    AssetID_8344 = -230.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.6 (نزدیک)
#    AssetID_9287 = 1.23 (نزدیک)
#
# --- درج رکورد 549 | TimeStamps=1755133031 ---
# رکورد درج شد.
#    AssetID_8342 = 11.3 (نزدیک)
#    AssetID_8343 = 70.0 (نزدیک)
#    AssetID_8344 = -233.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
#    AssetID_9287 = 1.28 (نزدیک)
#
# --- درج رکورد 550 | TimeStamps=1755118035 ---
# رکورد درج شد.
#    AssetID_8342 = 11.3 (نزدیک)
#    AssetID_8343 = 70.0 (نزدیک)
#    AssetID_8344 = -233.0 (نزدیک)
#    AssetID_8346 = 6.0 (نزدیک)
#    AssetID_9286 = 7.5 (نزدیک)
